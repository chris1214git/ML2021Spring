# %% [markdown]
# # Homework 11 - Transfer Learning (Domain Adversarial Training)
#
# > Author: Arvin Liu (r09922071@ntu.edu.tw)
#
# 若有任何問題，歡迎來信至助教信箱 ntu-ml-2021spring-ta@googlegroups.com

# %% [markdown]
# # Readme
#
#
# 這份作業的任務是Transfer Learning中的Domain Adversarial Training。
#
# <img src="https://i.imgur.com/iMVIxCH.png" width="500px">
#
# > 也就是左下角的那一塊。
#
# ## Scenario and Why Domain Adversarial Training
# 你現在有Source Data + label，其中Source Data和Target Data可能有點關係，所以你想要訓練一個model做在Source Data上並Predict在Target Data上。
#
# 但這樣有什麼樣的問題? 相信大家學過Anomaly Detection就會知道，如果有data是在Source Data沒有出現過的(或稱Abnormal的)，那麼model大部分都會因為不熟悉這個data而可能亂做一發。
#
# 以下我們將model拆成Feature Extractor(上半部)和Classifier(下半部)來作例子:
# <img src="https://i.imgur.com/IL0PxCY.png" width="500px">
#
# 整個Model在學習Source Data的時候，Feature Extrator因為看過很多次Source Data，所以所抽取出來的Feature可能就頗具意義，例如像圖上的藍色Distribution，已經將圖片分成各個Cluster，所以這個時候Classifier就可以依照這個Cluster去預測結果。
#
# 但是在做Target Data的時候，Feature Extractor會沒看過這樣的Data，導致輸出的Target Feature可能不屬於在Source Feature Distribution上，這樣的Feature給Classifier預測結果顯然就不會做得好。
#
# ## Domain Adversarial Training of Nerural Networks (DaNN)
# 基於如此，是不是只要讓Soucre Data和Target Data經過Feature Extractor都在同個Distribution上，就會做得好了呢? 這就是DaNN的主要核心。
#
# <img src="https://i.imgur.com/vrOE5a6.png" width="500px">
#
# 我們追加一個Domain Classifier，在學習的過程中，讓Domain Classifier去判斷經過Feature Extractor後的Feature是源自於哪個domain，讓Feature Extractor學習如何產生Feature以**騙過**Domain Classifier。 持久下來，通常Feature Extractor都會打贏Domain Classifier。(因為Domain Classifier的Input來自於Feature Extractor，而且對Feature Extractor來說Domain&Classification的任務並沒有衝突。)
#
# 如此一來，我們就可以確信不管是哪一個Domain，Feature Extractor都會把它產生在同一個Feature Distribution上。

# %% [markdown]
# # Data Introduce
#
# 這次的任務是Source Data: 真實照片，Target Data: 手畫塗鴉。
#
# 我們必須讓model看過真實照片以及標籤，嘗試去預測手畫塗鴉的標籤為何。
#
# 資料位於[這裡](https://drive.google.com/open?id=12-07DSquGdzN3JBHBChN4nMo3i8BqTiL)，以下的code分別為下載和觀看這次的資料大概長甚麼樣子。
#
# 特別注意一點: **這次的source和target data的圖片都是平衡的，你們可以使用這個資訊做其他事情。**

# %%
# # Download dataset
# !gdown --id '1P4fGNb9JhJj8W0DA_Qrp7mbrRHfF5U_f' --output real_or_drawing.zip
# # Unzip the files
# !unzip real_or_drawing.zip

# %%
import matplotlib.pyplot as plt

def no_axis_show(img, title='', cmap=None):
  # imshow, and set the interpolation mode to be "nearest"。
  fig = plt.imshow(img, interpolation='nearest', cmap=cmap)
  # do not show the axes in the images.
  fig.axes.get_xaxis().set_visible(False)
  fig.axes.get_yaxis().set_visible(False)
  plt.title(title)

titles = ['0 horse', '1 bed', '2 clock', '3 apple', '4 cat', '5 plane', '6 television', '7 dog', '8 dolphin', '9 spider']
plt.figure(figsize=(18, 18))
for i in range(10):
  plt.subplot(1, 10, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/train_data/{i}/{500*i}.bmp'), title=titles[i])

# %%
plt.figure(figsize=(18, 18))
for i in range(21):
  plt.subplot(1, 21, i+1)
  fig = no_axis_show(plt.imread(f'real_or_drawing/test_data/0/' + str(i).rjust(5, '0') + '.bmp'))

# %% [markdown]
# # Special Domain Knowledge
#
# 因為大家塗鴉的時候通常只會畫輪廓，我們可以根據這點將source data做點邊緣偵測處理，讓source data更像target data一點。
#
# ## Canny Edge Detection
# 算法這邊不贅述，只教大家怎麼用。若有興趣歡迎參考wiki或[這裡](https://medium.com/@pomelyu5199/canny-edge-detector-%E5%AF%A6%E4%BD%9C-opencv-f7d1a0a57d19)。
#
# cv2.Canny使用非常方便，只需要兩個參數: low_threshold, high_threshold。
#
# ```cv2.Canny(image, low_threshold, high_threshold)```
#
# 簡單來說就是當邊緣值超過high_threshold，我們就確定它是edge。如果只有超過low_threshold，那就先判斷一下再決定是不是edge。
#
# 以下我們直接拿source data做做看。

# %%
import cv2
import matplotlib.pyplot as plt
titles = ['horse', 'bed', 'clock', 'apple', 'cat', 'plane', 'television', 'dog', 'dolphin', 'spider']
plt.figure(figsize=(18, 18))

original_img = plt.imread(f'real_or_drawing/train_data/0/0.bmp')
plt.subplot(1, 5, 1)
no_axis_show(original_img, title='original')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

gray_img = cv2.cvtColor(original_img, cv2.COLOR_RGB2GRAY)
plt.subplot(1, 5, 2)
no_axis_show(gray_img, title='gray scale', cmap='gray')

canny_50100 = cv2.Canny(gray_img, 50, 100)
plt.subplot(1, 5, 3)
no_axis_show(canny_50100, title='Canny(50, 100)', cmap='gray')

canny_150200 = cv2.Canny(gray_img, 150, 200)
plt.subplot(1, 5, 4)
no_axis_show(canny_150200, title='Canny(150, 200)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 250, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(250, 300)', cmap='gray')

canny_250300 = cv2.Canny(gray_img, 270, 300)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(270, 300)', cmap='gray')
  
canny_250300 = cv2.Canny(gray_img, 320, 350)
plt.subplot(1, 5, 5)
no_axis_show(canny_250300, title='Canny(320, 350)', cmap='gray')

# %% [markdown]
# # Data Process
#
# 在這裡我故意將data用成可以使用torchvision.ImageFolder的形式，所以只要使用該函式便可以做出一個datasets。
#
# transform的部分請參考以下註解。
# <!--
# #### 一些細節
#
# 在一般的版本上，對灰階圖片使用RandomRotation使用```transforms.RandomRotation(15)```即可。但在colab上需要加上```fill=(0,)```才可運行。
# 在n98上執行需要把```fill=(0,)```拿掉才可運行。 -->

# %%
import os

gpu_id = 3
os.environ['CUDA_VISIBLE_DEVICES'] = str(gpu_id)

# %%
Canny_setting = [270, 300]

# %%
import numpy as np
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.autograd import Function

import torch.optim as optim
import torchvision.transforms as transforms
from torchvision.datasets import ImageFolder
from torch.utils.data import DataLoader

source_transform = transforms.Compose([
    # Turn RGB to grayscale. (Bacause Canny do not support RGB images.)
    transforms.Grayscale(),
    # cv2 do not support skimage.Image, so we transform it to np.array, 
    # and then adopt cv2.Canny algorithm.
    transforms.Lambda(lambda x: cv2.Canny(np.array(x), Canny_setting[0], Canny_setting[1])),
    # Transform np.array back to the skimage.Image.
    transforms.ToPILImage(),
    # 50% Horizontal Flip. (For Augmentation)
    
    transforms.RandomAffine(10 , translate = (0.1 , 0.1) , scale = (0.9 , 1.1)) ,
#     transforms.RandomCrop(32, padding=4),
    
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
#     transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])
target_transform = transforms.Compose([
    # Turn RGB to grayscale.
    transforms.Grayscale(),
    # Resize: size of source data is 32x32, thus we need to 
    #  enlarge the size of target data from 28x28 to 32x32。
    transforms.Resize((32, 32)),
    # 50% Horizontal Flip. (For Augmentation)
    
    transforms.RandomHorizontalFlip(),
    # Rotate +- 15 degrees. (For Augmentation), and filled with zero 
    # if there's empty pixel after rotation.
    transforms.RandomRotation(15, fill=(0,)),
    # Transform to tensor for model inputs.
    transforms.ToTensor(),
])

source_dataset = ImageFolder('real_or_drawing/train_data', transform=source_transform)
target_dataset = ImageFolder('real_or_drawing/test_data', transform=target_transform)

source_dataloader = DataLoader(source_dataset, batch_size=32, shuffle=True)
target_dataloader = DataLoader(target_dataset, batch_size=32, shuffle=True)
test_dataloader = DataLoader(target_dataset, batch_size=128, shuffle=False)

# %% [markdown]
# # Model
#
# Feature Extractor: 典型的VGG-like疊法。
#
# Label Predictor / Domain Classifier: MLP到尾。
#
# 相信作業寫到這邊大家對以下的Layer都很熟悉，因此不再贅述。

# %%
class FeatureExtractor(nn.Module):

    def __init__(self):
        super(FeatureExtractor, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(1, 64, 3, 1, 1),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(64, 128, 3, 1, 1),
            nn.BatchNorm2d(128),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(128, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 256, 3, 1, 1),
            nn.BatchNorm2d(256),
            nn.ReLU(),
            nn.MaxPool2d(2),

            nn.Conv2d(256, 512, 3, 1, 1),
            nn.BatchNorm2d(512),
            nn.ReLU(),
            nn.MaxPool2d(2)
        )
        
    def forward(self, x):
        x = self.conv(x).squeeze()
        return x

class LabelPredictor(nn.Module):

    def __init__(self):
        super(LabelPredictor, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.ReLU(),

            nn.Linear(512, 10),
        )

    def forward(self, h):
        c = self.layer(h)
        return c

class DomainClassifier(nn.Module):

    def __init__(self):
        super(DomainClassifier, self).__init__()

        self.layer = nn.Sequential(
            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 512),
            nn.BatchNorm1d(512),
            nn.ReLU(),

            nn.Linear(512, 1),
        )

    def forward(self, h):
        y = self.layer(h)
        return y

# %% [markdown]
# # Pre-processing
#
# 這裡我們選用Adam來當Optimizer。

# %%
feature_extractor = FeatureExtractor().cuda()
label_predictor = LabelPredictor().cuda()
domain_classifier = DomainClassifier().cuda()

class_criterion = nn.CrossEntropyLoss()
domain_criterion = nn.BCEWithLogitsLoss()

optimizer_F = optim.Adam(feature_extractor.parameters())
optimizer_C = optim.Adam(label_predictor.parameters())
optimizer_D = optim.Adam(domain_classifier.parameters())

# %% [markdown]
# # Start Training
#
#
# ## 如何實作DaNN?
#
# 理論上，在原始paper中是加上Gradient Reversal Layer，並將Feature Extractor / Label Predictor / Domain Classifier 一起train，但其實我們也可以交換的train Domain Classfier & Feature Extractor(就像在train GAN的Generator & Discriminator一樣)，這也是可行的。
#
# 在code實現中，我們採取後者的方式，畢竟GAN是之前的作業，應該會比較熟悉:)。
#
# ## 小提醒
# * 原文中的lambda(控制Domain Adversarial Loss的係數)是有Adaptive的版本，如果有興趣可以參考[原文](https://arxiv.org/pdf/1505.07818.pdf)。
# * 因為我們完全沒有target的label，所以結果如何，只好丟kaggle看看囉:)?

# %%
import math
total_epoch = 2000
lamb_decay = 10

# %%
def train_epoch(source_dataloader, target_dataloader, lamb):
    '''
      Args:
        source_dataloader: source data的dataloader
        target_dataloader: target data的dataloader
        lamb: control the balance of domain adaptatoin and classification.
    '''

    # D loss: Domain Classifier的loss
    # F loss: Feature Extrator & Label Predictor的loss
    running_D_loss, running_F_loss = 0.0, 0.0
    total_hit, total_num = 0.0, 0.0

    for i, ((source_data, source_label), (target_data, _)) in enumerate(zip(source_dataloader, target_dataloader)):

        source_data = source_data.cuda()
        source_label = source_label.cuda()
        target_data = target_data.cuda()
        
        # Mixed the source data and target data, or it'll mislead the running params
        #   of batch_norm. (runnning mean/var of soucre and target data are different.)
        mixed_data = torch.cat([source_data, target_data], dim=0)
        domain_label = torch.zeros([source_data.shape[0] + target_data.shape[0], 1]).cuda()
        # set domain label of source data to be 1.
        domain_label[:source_data.shape[0]] = 1

        # Step 1 : train domain classifier
        feature = feature_extractor(mixed_data)
        # We don't need to train feature extractor in step 1.
        # Thus we detach the feature neuron to avoid backpropgation.
        domain_logits = domain_classifier(feature.detach())
        loss = domain_criterion(domain_logits, domain_label)
        running_D_loss+= loss.item()
        loss.backward()
        optimizer_D.step()

        # Step 2 : train feature extractor and label classifier
        class_logits = label_predictor(feature[:source_data.shape[0]])
        domain_logits = domain_classifier(feature)
        # loss = cross entropy of classification - lamb * domain binary cross entropy.
        #  The reason why using subtraction is similar to generator loss in disciminator of GAN
        loss = class_criterion(class_logits, source_label) - lamb * domain_criterion(domain_logits, domain_label)
        running_F_loss+= loss.item()
        loss.backward()
        optimizer_F.step()
        optimizer_C.step()

        optimizer_D.zero_grad()
        optimizer_F.zero_grad()
        optimizer_C.zero_grad()

        total_hit += torch.sum(torch.argmax(class_logits, dim=1) == source_label).item()
        total_num += source_data.shape[0]
        print(i, end='\r')

    return running_D_loss / (i+1), running_F_loss / (i+1), total_hit / total_num

# train 200 epochs
for epoch in range(total_epoch):
    # You should chooose lamnda cleverly.
    lamb = 2 / (1 + math.exp(-lamb_decay * epoch / total_epoch)) - 1
    train_D_loss, train_F_loss, train_acc = train_epoch(source_dataloader, target_dataloader, lamb=lamb)

    torch.save(feature_extractor.state_dict(), f'extractor_model.bin')
    torch.save(label_predictor.state_dict(), f'predictor_model.bin')

    print('epoch {:>3d}: train D loss: {:6.4f}, train F loss: {:6.4f}, acc {:6.4f}'.format(epoch, train_D_loss, train_F_loss, train_acc))
# Out:
# epoch   0: train D loss: 0.2204, train F loss: 1.9787, acc 0.2678
# epoch   1: train D loss: 0.3028, train F loss: 1.7034, acc 0.3890
# epoch   2: train D loss: 0.2896, train F loss: 1.5974, acc 0.4350
# epoch   3: train D loss: 0.2614, train F loss: 1.5212, acc 0.4670
# epoch   4: train D loss: 0.2853, train F loss: 1.4606, acc 0.4934
# epoch   5: train D loss: 0.2656, train F loss: 1.4297, acc 0.4972
# epoch   6: train D loss: 0.3134, train F loss: 1.4046, acc 0.5130
# epoch   7: train D loss: 0.2962, train F loss: 1.3690, acc 0.5256
# epoch   8: train D loss: 0.3123, train F loss: 1.3553, acc 0.5228
# epoch   9: train D loss: 0.3111, train F loss: 1.3100, acc 0.5430
# epoch  10: train D loss: 0.3161, train F loss: 1.3075, acc 0.5380
# epoch  11: train D loss: 0.2913, train F loss: 1.2740, acc 0.5524
# epoch  12: train D loss: 0.3070, train F loss: 1.2549, acc 0.5660
# epoch  13: train D loss: 0.2840, train F loss: 1.2345, acc 0.5652
# epoch  14: train D loss: 0.2831, train F loss: 1.2095, acc 0.5792
# epoch  15: train D loss: 0.2722, train F loss: 1.1888, acc 0.5758
# epoch  16: train D loss: 0.3005, train F loss: 1.1770, acc 0.5914
# epoch  17: train D loss: 0.3033, train F loss: 1.1560, acc 0.5952
# epoch  18: train D loss: 0.3164, train F loss: 1.1311, acc 0.5956
# epoch  19: train D loss: 0.3021, train F loss: 1.1244, acc 0.6092
# epoch  20: train D loss: 0.3189, train F loss: 1.1129, acc 0.6114
# epoch  21: train D loss: 0.3189, train F loss: 1.0809, acc 0.6190
# epoch  22: train D loss: 0.3098, train F loss: 1.0749, acc 0.6328
# epoch  23: train D loss: 0.3204, train F loss: 1.0509, acc 0.6286
# epoch  24: train D loss: 0.3301, train F loss: 1.0391, acc 0.6330
# epoch  25: train D loss: 0.3214, train F loss: 1.0110, acc 0.6440
# epoch  26: train D loss: 0.3412, train F loss: 0.9984, acc 0.6442
# epoch  27: train D loss: 0.3243, train F loss: 0.9839, acc 0.6466
# epoch  28: train D loss: 0.3374, train F loss: 0.9811, acc 0.6490
# epoch  29: train D loss: 0.3387, train F loss: 0.9557, acc 0.6598
# epoch  30: train D loss: 0.3514, train F loss: 0.9428, acc 0.6632
# epoch  31: train D loss: 0.3464, train F loss: 0.9119, acc 0.6682
# epoch  32: train D loss: 0.3410, train F loss: 0.8895, acc 0.6778
# epoch  33: train D loss: 0.3281, train F loss: 0.8867, acc 0.6804
# epoch  34: train D loss: 0.3306, train F loss: 0.8876, acc 0.6884
# epoch  35: train D loss: 0.3425, train F loss: 0.8303, acc 0.6928
# epoch  36: train D loss: 0.3426, train F loss: 0.8376, acc 0.7024
# epoch  37: train D loss: 0.3279, train F loss: 0.8242, acc 0.6958
# epoch  38: train D loss: 0.3398, train F loss: 0.7944, acc 0.7136
# epoch  39: train D loss: 0.3412, train F loss: 0.7751, acc 0.7194
# epoch  40: train D loss: 0.3530, train F loss: 0.7740, acc 0.7184
# epoch  41: train D loss: 0.3523, train F loss: 0.7512, acc 0.7318
# epoch  42: train D loss: 0.3466, train F loss: 0.7440, acc 0.7268
# epoch  43: train D loss: 0.3470, train F loss: 0.7130, acc 0.7380
# epoch  44: train D loss: 0.3618, train F loss: 0.6970, acc 0.7384
# epoch  45: train D loss: 0.3515, train F loss: 0.6887, acc 0.7442
# epoch  46: train D loss: 0.3505, train F loss: 0.7015, acc 0.7436
# epoch  47: train D loss: 0.3457, train F loss: 0.6768, acc 0.7526
# epoch  48: train D loss: 0.3622, train F loss: 0.6479, acc 0.7598
# epoch  49: train D loss: 0.3424, train F loss: 0.6244, acc 0.7674
# epoch  50: train D loss: 0.3645, train F loss: 0.6290, acc 0.7680
# epoch  51: train D loss: 0.3636, train F loss: 0.6191, acc 0.7666
# epoch  52: train D loss: 0.3509, train F loss: 0.5940, acc 0.7752
# epoch  53: train D loss: 0.3594, train F loss: 0.5568, acc 0.7928
# epoch  54: train D loss: 0.3477, train F loss: 0.5746, acc 0.7806
# epoch  55: train D loss: 0.3527, train F loss: 0.5392, acc 0.7938
# epoch  56: train D loss: 0.3621, train F loss: 0.5245, acc 0.7972
# epoch  57: train D loss: 0.3567, train F loss: 0.5317, acc 0.7990
# epoch  58: train D loss: 0.3780, train F loss: 0.5180, acc 0.8032
# epoch  59: train D loss: 0.3603, train F loss: 0.5192, acc 0.8024
# epoch  60: train D loss: 0.3927, train F loss: 0.5011, acc 0.8086
# epoch  61: train D loss: 0.3720, train F loss: 0.4641, acc 0.8188
# epoch  62: train D loss: 0.3745, train F loss: 0.4391, acc 0.8296
# epoch  63: train D loss: 0.3733, train F loss: 0.4761, acc 0.8198
# epoch  64: train D loss: 0.3836, train F loss: 0.4391, acc 0.8308
# epoch  65: train D loss: 0.3840, train F loss: 0.4301, acc 0.8336
# epoch  66: train D loss: 0.3799, train F loss: 0.4470, acc 0.8244
# epoch  67: train D loss: 0.3888, train F loss: 0.4212, acc 0.8326
# epoch  68: train D loss: 0.3926, train F loss: 0.4129, acc 0.8308
# epoch  69: train D loss: 0.3695, train F loss: 0.3927, acc 0.8414
# epoch  70: train D loss: 0.3850, train F loss: 0.3994, acc 0.8388
# epoch  71: train D loss: 0.3725, train F loss: 0.3790, acc 0.8466
# epoch  72: train D loss: 0.3793, train F loss: 0.3552, acc 0.8560
# epoch  73: train D loss: 0.3798, train F loss: 0.3643, acc 0.8536
# epoch  74: train D loss: 0.3866, train F loss: 0.3357, acc 0.8598
# epoch  75: train D loss: 0.3822, train F loss: 0.3468, acc 0.8604
# epoch  76: train D loss: 0.4066, train F loss: 0.3269, acc 0.8638
# epoch  77: train D loss: 0.4073, train F loss: 0.3289, acc 0.8672
# epoch  78: train D loss: 0.3958, train F loss: 0.3218, acc 0.8670
# epoch  79: train D loss: 0.3875, train F loss: 0.3262, acc 0.8648
# epoch  80: train D loss: 0.3870, train F loss: 0.3242, acc 0.8606
# epoch  81: train D loss: 0.3991, train F loss: 0.3077, acc 0.8650
# epoch  82: train D loss: 0.3951, train F loss: 0.3098, acc 0.8762
# epoch  83: train D loss: 0.4025, train F loss: 0.2803, acc 0.8736
# epoch  84: train D loss: 0.4097, train F loss: 0.2877, acc 0.8772
# epoch  85: train D loss: 0.4061, train F loss: 0.2825, acc 0.8798
# epoch  86: train D loss: 0.4041, train F loss: 0.2702, acc 0.8748
# epoch  87: train D loss: 0.4087, train F loss: 0.2743, acc 0.8806
# epoch  88: train D loss: 0.4160, train F loss: 0.2541, acc 0.8852
# epoch  89: train D loss: 0.4177, train F loss: 0.2607, acc 0.8868
# epoch  90: train D loss: 0.4174, train F loss: 0.2639, acc 0.8850
# epoch  91: train D loss: 0.4073, train F loss: 0.2485, acc 0.8880
# epoch  92: train D loss: 0.4074, train F loss: 0.2390, acc 0.8932
# epoch  93: train D loss: 0.4167, train F loss: 0.2450, acc 0.8884
# epoch  94: train D loss: 0.4100, train F loss: 0.2287, acc 0.8934
# epoch  95: train D loss: 0.4166, train F loss: 0.2143, acc 0.8938
# epoch  96: train D loss: 0.4077, train F loss: 0.2406, acc 0.8880
# epoch  97: train D loss: 0.4245, train F loss: 0.2116, acc 0.8974
# epoch  98: train D loss: 0.4322, train F loss: 0.2141, acc 0.8920
# epoch  99: train D loss: 0.4297, train F loss: 0.2122, acc 0.9020
# epoch 100: train D loss: 0.4395, train F loss: 0.1927, acc 0.9020
# epoch 101: train D loss: 0.4256, train F loss: 0.1759, acc 0.9078
# epoch 102: train D loss: 0.4442, train F loss: 0.1997, acc 0.8958
# epoch 103: train D loss: 0.4418, train F loss: 0.2028, acc 0.8982
# epoch 104: train D loss: 0.4371, train F loss: 0.1947, acc 0.9008
# epoch 105: train D loss: 0.4502, train F loss: 0.1878, acc 0.9042
# epoch 106: train D loss: 0.4498, train F loss: 0.1686, acc 0.9088
# epoch 107: train D loss: 0.4519, train F loss: 0.1753, acc 0.9016
# epoch 108: train D loss: 0.4517, train F loss: 0.1528, acc 0.9106
# epoch 110: train D loss: 0.4586, train F loss: 0.1447, acc 0.9126
# epoch 111: train D loss: 0.4671, train F loss: 0.1482, acc 0.9094
# epoch 112: train D loss: 0.4572, train F loss: 0.1724, acc 0.9026
# epoch 113: train D loss: 0.4643, train F loss: 0.1457, acc 0.9064
# epoch 114: train D loss: 0.4572, train F loss: 0.1573, acc 0.9070
# epoch 115: train D loss: 0.4760, train F loss: 0.1442, acc 0.9074
# epoch 116: train D loss: 0.4616, train F loss: 0.1526, acc 0.9068
# epoch 117: train D loss: 0.4678, train F loss: 0.1325, acc 0.9122
# epoch 118: train D loss: 0.4525, train F loss: 0.1341, acc 0.9176
# epoch 119: train D loss: 0.4753, train F loss: 0.1355, acc 0.9088
# epoch 120: train D loss: 0.4899, train F loss: 0.1267, acc 0.9106
# epoch 121: train D loss: 0.4719, train F loss: 0.1052, acc 0.9240
# epoch 122: train D loss: 0.4862, train F loss: 0.1017, acc 0.9244
# epoch 123: train D loss: 0.4865, train F loss: 0.1102, acc 0.9148
# epoch 124: train D loss: 0.4974, train F loss: 0.1097, acc 0.9168
# epoch 125: train D loss: 0.4777, train F loss: 0.1177, acc 0.9148
# epoch 126: train D loss: 0.4942, train F loss: 0.1053, acc 0.9188
# epoch 127: train D loss: 0.5051, train F loss: 0.0751, acc 0.9234
# epoch 128: train D loss: 0.4947, train F loss: 0.1065, acc 0.9164
# epoch 129: train D loss: 0.5099, train F loss: 0.0819, acc 0.9216
# epoch 130: train D loss: 0.4912, train F loss: 0.0832, acc 0.9248
# epoch 131: train D loss: 0.4859, train F loss: 0.1023, acc 0.9214
# epoch 132: train D loss: 0.5000, train F loss: 0.0780, acc 0.9244
# epoch 133: train D loss: 0.4964, train F loss: 0.0964, acc 0.9206
# epoch 134: train D loss: 0.4973, train F loss: 0.0823, acc 0.9216
# epoch 135: train D loss: 0.5026, train F loss: 0.0763, acc 0.9248
# epoch 136: train D loss: 0.5097, train F loss: 0.0773, acc 0.9176
# epoch 137: train D loss: 0.4919, train F loss: 0.0625, acc 0.9288
# epoch 138: train D loss: 0.5051, train F loss: 0.0755, acc 0.9254
# epoch 139: train D loss: 0.5161, train F loss: 0.0635, acc 0.9258
# epoch 140: train D loss: 0.5044, train F loss: 0.0374, acc 0.9332
# epoch 141: train D loss: 0.4989, train F loss: 0.0587, acc 0.9264
# epoch 142: train D loss: 0.5186, train F loss: 0.0770, acc 0.9160
# epoch 143: train D loss: 0.5080, train F loss: 0.0429, acc 0.9274
# epoch 144: train D loss: 0.5039, train F loss: 0.0536, acc 0.9282
# epoch 145: train D loss: 0.5215, train F loss: 0.0601, acc 0.9214
# epoch 146: train D loss: 0.5172, train F loss: 0.0542, acc 0.9222
# epoch 147: train D loss: 0.5123, train F loss: 0.0468, acc 0.9270
# epoch 148: train D loss: 0.5187, train F loss: 0.0159, acc 0.9340
# epoch 149: train D loss: 0.5088, train F loss: 0.0201, acc 0.9324
# epoch 150: train D loss: 0.5204, train F loss: 0.0293, acc 0.9298
# epoch 151: train D loss: 0.5216, train F loss: 0.0322, acc 0.9254
# epoch 152: train D loss: 0.5218, train F loss: 0.0276, acc 0.9282
# epoch 153: train D loss: 0.5341, train F loss: 0.0398, acc 0.9292
# epoch 154: train D loss: 0.5209, train F loss: 0.0105, acc 0.9356
# epoch 155: train D loss: 0.5383, train F loss: 0.0143, acc 0.9324
# epoch 156: train D loss: 0.5280, train F loss: 0.0335, acc 0.9292
# epoch 157: train D loss: 0.5293, train F loss: 0.0139, acc 0.9322
# epoch 158: train D loss: 0.5368, train F loss: 0.0074, acc 0.9340
# epoch 159: train D loss: 0.5260, train F loss: -0.0051, acc 0.9390
# epoch 160: train D loss: 0.5363, train F loss: 0.0126, acc 0.9304
# epoch 161: train D loss: 0.5208, train F loss: -0.0005, acc 0.9392
# epoch 162: train D loss: 0.5301, train F loss: 0.0094, acc 0.9368
# epoch 163: train D loss: 0.5478, train F loss: -0.0065, acc 0.9372
# epoch 164: train D loss: 0.5470, train F loss: -0.0020, acc 0.9324
# epoch 165: train D loss: 0.5475, train F loss: -0.0061, acc 0.9342
# epoch 166: train D loss: 0.5396, train F loss: -0.0104, acc 0.9346
# epoch 167: train D loss: 0.5430, train F loss: -0.0206, acc 0.9370
# epoch 168: train D loss: 0.5428, train F loss: -0.0060, acc 0.9320
# epoch 169: train D loss: 0.5415, train F loss: -0.0196, acc 0.9388
# epoch 170: train D loss: 0.5510, train F loss: -0.0028, acc 0.9308
# epoch 171: train D loss: 0.5353, train F loss: -0.0277, acc 0.9362
# epoch 172: train D loss: 0.5546, train F loss: -0.0387, acc 0.9404
# epoch 173: train D loss: 0.5452, train F loss: -0.0214, acc 0.9386
# epoch 174: train D loss: 0.5505, train F loss: -0.0126, acc 0.9334
# epoch 175: train D loss: 0.5530, train F loss: -0.0307, acc 0.9404
# epoch 176: train D loss: 0.5583, train F loss: -0.0338, acc 0.9348
# epoch 177: train D loss: 0.5377, train F loss: -0.0223, acc 0.9366
# epoch 178: train D loss: 0.5540, train F loss: -0.0151, acc 0.9270
# epoch 179: train D loss: 0.5457, train F loss: -0.0334, acc 0.9396
# epoch 180: train D loss: 0.5631, train F loss: -0.0427, acc 0.9380
# epoch 181: train D loss: 0.5632, train F loss: -0.0375, acc 0.9342
# epoch 182: train D loss: 0.5553, train F loss: -0.0326, acc 0.9358
# epoch 183: train D loss: 0.5415, train F loss: -0.0354, acc 0.9366
# epoch 184: train D loss: 0.5514, train F loss: -0.0570, acc 0.9426
# epoch 185: train D loss: 0.5568, train F loss: -0.0479, acc 0.9382
# epoch 186: train D loss: 0.5540, train F loss: -0.0584, acc 0.9436
# epoch 187: train D loss: 0.5533, train F loss: -0.0460, acc 0.9410
# epoch 188: train D loss: 0.5543, train F loss: -0.0510, acc 0.9418
# epoch 189: train D loss: 0.5600, train F loss: -0.0547, acc 0.9410
# epoch 190: train D loss: 0.5674, train F loss: -0.0621, acc 0.9386
# epoch 191: train D loss: 0.5690, train F loss: -0.0701, acc 0.9424
# epoch 192: train D loss: 0.5579, train F loss: -0.0501, acc 0.9390
# epoch 193: train D loss: 0.5547, train F loss: -0.0498, acc 0.9382
# epoch 194: train D loss: 0.5565, train F loss: -0.0714, acc 0.9434
# epoch 195: train D loss: 0.5596, train F loss: -0.0675, acc 0.9426
# epoch 196: train D loss: 0.5618, train F loss: -0.0691, acc 0.9464
# epoch 197: train D loss: 0.5729, train F loss: -0.0627, acc 0.9368
# epoch 198: train D loss: 0.5667, train F loss: -0.0728, acc 0.9416
# epoch 199: train D loss: 0.5684, train F loss: -0.0920, acc 0.9458
# epoch 200: train D loss: 0.5700, train F loss: -0.0932, acc 0.9462
# epoch 201: train D loss: 0.5757, train F loss: -0.0851, acc 0.9444
# epoch 202: train D loss: 0.5669, train F loss: -0.0706, acc 0.9388
# epoch 203: train D loss: 0.5691, train F loss: -0.0811, acc 0.9428
# epoch 204: train D loss: 0.5752, train F loss: -0.0994, acc 0.9470
# epoch 205: train D loss: 0.5743, train F loss: -0.0817, acc 0.9406
# epoch 206: train D loss: 0.5692, train F loss: -0.0877, acc 0.9396
# epoch 207: train D loss: 0.5707, train F loss: -0.0867, acc 0.9426
# epoch 208: train D loss: 0.5632, train F loss: -0.0949, acc 0.9444
# epoch 209: train D loss: 0.5697, train F loss: -0.0894, acc 0.9444
# epoch 210: train D loss: 0.5712, train F loss: -0.1125, acc 0.9492
# epoch 211: train D loss: 0.5732, train F loss: -0.1008, acc 0.9470
# epoch 212: train D loss: 0.5728, train F loss: -0.1070, acc 0.9498
# epoch 213: train D loss: 0.5731, train F loss: -0.1004, acc 0.9464
# epoch 214: train D loss: 0.5917, train F loss: -0.1150, acc 0.9462
# epoch 215: train D loss: 0.5800, train F loss: -0.1125, acc 0.9512
# epoch 216: train D loss: 0.5646, train F loss: -0.0989, acc 0.9450
# epoch 217: train D loss: 0.5667, train F loss: -0.1233, acc 0.9508
# epoch 218: train D loss: 0.5728, train F loss: -0.1044, acc 0.9442
# epoch 219: train D loss: 0.5834, train F loss: -0.1149, acc 0.9456
# epoch 220: train D loss: 0.5701, train F loss: -0.1169, acc 0.9468
# epoch 221: train D loss: 0.5792, train F loss: -0.1103, acc 0.9426
# epoch 222: train D loss: 0.5854, train F loss: -0.1340, acc 0.9494
# epoch 223: train D loss: 0.5754, train F loss: -0.1052, acc 0.9424
# epoch 224: train D loss: 0.5756, train F loss: -0.1083, acc 0.9440
# epoch 225: train D loss: 0.5769, train F loss: -0.1242, acc 0.9470
# epoch 226: train D loss: 0.5705, train F loss: -0.1095, acc 0.9470
# 27

# %% [markdown]
# # Inference
#
# 就跟前幾次作業一樣。這裡我使用pd來生產csv，因為看起來比較潮(?)
#
# 此外，200 epochs的Accuracy可能會不太穩定，可以多丟幾次或train久一點。

# %%
result = []
label_predictor.eval()
feature_extractor.eval()
for i, (test_data, _) in enumerate(test_dataloader):
    test_data = test_data.cuda()

    class_logits = label_predictor(feature_extractor(test_data))

    x = torch.argmax(class_logits, dim=1).cpu().detach().numpy()
    result.append(x)

import pandas as pd
result = np.concatenate(result)

# Generate your submission
df = pd.DataFrame({'id': np.arange(0,len(result)), 'label': result})
df.to_csv('DaNN_submission.csv',index=False)

# %% [markdown]
# # Training Statistics
#
# - Number of parameters:
#   - Feature Extractor: 2, 142, 336
#   - Label Predictor: 530, 442
#   - Domain Classifier: 1, 055, 233
#
# - Simple
#  - Training time on colab: ~ 1 hr
# - Medium
#  - Training time on colab: 2 ~ 4 hr
# - Strong
#  - Training time on colab: 5 ~ 6 hrs
# - Boss
#  - **Unmeasurable**

# %% [markdown]
# # Learning Curve (Strong Baseline)
# * This method is slightly different from colab.
#
# ![Loss Curve](https://i.imgur.com/vIujQyo.png)
#
# # Accuracy Curve (Strong Baseline)
# * Note that you cannot access testing accuracy. But this plot tells you that even though the model overfits the training data, the testing accuracy is still improving, and that's why you need to train more epochs.
#
# ![Acc Curve](https://i.imgur.com/4W1otXG.png)

# %% [markdown]
# # Q&A
#
# 有任何問題 Domain Adaptation 的問題可以寄信到ntu-ml-2021spring-ta@googlegroups.com。
#
# 時間允許的話我會更新在這裡。
#
# # Special Thanks
# 這次的作業其實是我出在 2019FALL 的 ML Final Project，以下是我認為在 Final Report 不錯的幾組，有興趣的話歡迎大家參考看看。
#
# [NTU_r08942071_太神啦 / 組長: 劉正仁同學](https://drive.google.com/open?id=11uNDcz7_eMS8dMQxvnWsbrdguu9k4c-c)
#
# [NTU_r08921a08_CAT / 組長: 廖子毅同學](https://drive.google.com/open?id=1xIkSs8HAShdcfV1E0NEnf4JDbL7POZTf)
